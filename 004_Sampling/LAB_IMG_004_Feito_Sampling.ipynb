# %% [markdown]
# # Importar librerías

# %%
# !pip install scikit-image watermark -q

# Install OpenCV package first
# !pip install opencv-python -q

# First install the required system library
# !apt-get update && apt-get install -y libgl1-mesa-glx

# !pip install opencv-python
# Out:
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Hit:1 http://deb.debian.org/debian bullseye InRelease
# Hit:2 http://deb.debian.org/debian-security bullseye-security InRelease
# Hit:3 http://deb.debian.org/debian bullseye-updates InRelease
#
#
#
#
# libgl1-mesa-glx is already the newest version (20.3.5-1).
# 0 upgraded, 0 newly installed, 0 to remove and 44 not upgraded.
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
from cv2 import imread
import matplotlib.pyplot as plt

# %%
# !wget https://ucf018524313fc155e0c27735d4c.previews.dropboxusercontent.com/p/thumb/ACn51w5HVrMIFo03qJ2L4q_TPChCKz2rB229Nic1v0bBwGifH1pujB8j7vEMKJRo8Kj-wwEwYOcbt5nZ7D0x72HrSXn07AFPwLxl5CVI4T2y4GywUZfKcLi9tSIHcHPOJ3xk7szaKmIj7dk211vRVKyOGZsO04cE13m374WkTPv9rEYTAVDRIj584KyFY1dYKaYhPJijv6p5h4GXpzedP9HEaqIb6by1fuvEuR07ke4J3jgQ4vIf8eVks8KaHCeAjvU3rihw_G7D12xEwnc69dUg8Mt8Y37_qck8R0z1bVVZDO02LsSGRo8cuQ2VbXRVVpCx-q22zxKXQ8kYnKWuzQWlyk97t3kqvDixZUKWZy-_ume1fN4ObJmISibquYBubZ4/p.png?is_prewarmed=true
# Out:
# --2025-04-09 01:23:08--  https://ucf018524313fc155e0c27735d4c.previews.dropboxusercontent.com/p/thumb/ACn51w5HVrMIFo03qJ2L4q_TPChCKz2rB229Nic1v0bBwGifH1pujB8j7vEMKJRo8Kj-wwEwYOcbt5nZ7D0x72HrSXn07AFPwLxl5CVI4T2y4GywUZfKcLi9tSIHcHPOJ3xk7szaKmIj7dk211vRVKyOGZsO04cE13m374WkTPv9rEYTAVDRIj584KyFY1dYKaYhPJijv6p5h4GXpzedP9HEaqIb6by1fuvEuR07ke4J3jgQ4vIf8eVks8KaHCeAjvU3rihw_G7D12xEwnc69dUg8Mt8Y37_qck8R0z1bVVZDO02LsSGRo8cuQ2VbXRVVpCx-q22zxKXQ8kYnKWuzQWlyk97t3kqvDixZUKWZy-_ume1fN4ObJmISibquYBubZ4/p.png?is_prewarmed=true
# Resolving ucf018524313fc155e0c27735d4c.previews.dropboxusercontent.com (ucf018524313fc155e0c27735d4c.previews.dropboxusercontent.com)... 162.125.6.16, 2620:100:601c:16::a27d:610
# Connecting to ucf018524313fc155e0c27735d4c.previews.dropboxusercontent.com (ucf018524313fc155e0c27735d4c.previews.dropboxusercontent.com)|162.125.6.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/png]
# Saving to: ‘p.png?is_prewarmed=true.2’
#
# ...

# %%
def data_img(img):
    print('size = ', img.shape)
    print('max = ', inp.max(img))
    print('min = ', inp.min(img))

# %%
img_example = 'p.png'

# %%
img = imread(img_example)  # Using the available image file
# Out:
# libpng warning: iCCP: profile 'ICC Profile': 'RGB ': RGB color space not permitted on grayscale PNG

# %%
X = img[:,:,0]

# %%
plt.figure(figsize=(5,5))
plt.imshow(X,cmap='gray')
plt.show()

# %%
def data_img(img):
    print('size = ', img.shape)
    print('max = ', np.max(img))  # Using np.max
    print('min = ', np.min(img))  # Using np.min

# Now run the main code
d = 2 
(Nx,Mx) = X.shape
ix = range(0,Nx,d)
jx = range(0,Mx,d)
Ny = len(ix)
My = len(jx)
Y = np.zeros((Ny,My),np.uint8)
for i in range(Ny):
    for j in range(My):
        Y[i,j] = X[ix[i],jx[j]]
plt.figure(figsize=(8,8))
plt.imshow(Y,cmap='gray')
plt.show()
data_img(Y)
# Out:
# size =  (256, 256)
# max =  246
# min =  0

# %%
p = 64

# %%
(Nx,Mx) = X.shape
Ny = Nx
My = Mx
Y = np.zeros((Ny,My),np.uint8)
for i in range(Ny):
  for j in range(My):
    x = int(np.fix(X[i,j]/p)*p)
    Y[i,j] = x
plt.figure(figsize=(8,8))
plt.imshow(Y,cmap='gray')
plt.show()
data_img(Y)  # Using the correct function name data_img() instead of howis()
print('This image has = ',int(256/p),' grayvalues')
# Out:
# size =  (512, 512)
# max =  192
# min =  0
# This image has =  4  grayvalues

# %%
def imhist(X,n=256):
  (N,M) = X.shape
  h = np.zeros((n,))
  for i in range(N):
    for j in range(M):
      x = X[i,j]
      h[x] = h[x]+1
  return h

# %%
#una manera por ahi más sencilla es esta:
def ScaleGray(img: np.ndarray, d: int) -> np.ndarray:
    return np.floor_divide(img, d)*d

# %% [markdown]
# > !wget https://www.dropbox.com/s/vjxcddg5rgap35i/scale.png

# %% [markdown]
# I'll help you download the image from Dropbox using wget. Let me execute that command:

# %%
# !wget https://www.dropbox.com/s/vjxcddg5rgap35i/scale.png
# Out:
# --2025-04-09 01:25:23--  https://www.dropbox.com/s/vjxcddg5rgap35i/scale.png
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.6.18, 2620:100:601c:18::a27d:612
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.6.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/bo3p5wust5leilgoqq2wm/scale.png?rlkey=jbevth8oqwbgkk4t9az8seq9w [following]
# --2025-04-09 01:25:23--  https://www.dropbox.com/scl/fi/bo3p5wust5leilgoqq2wm/scale.png?rlkey=jbevth8oqwbgkk4t9az8seq9w
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucf23d48fbc42ac58fe01dc426f4.dl.dropboxusercontent.com/cd/0/inline/CncXO7IkJsV8Yf3ooSvxAfmsxps4_2ArtPyVnCadpVWO1DPPTldNvEbMFsasy0asQeOzh8Zd2feHbdWxf5U8p_vn3srBTwH_wBmt9dIJ3arei62jvYs6yJaub92xj-adOzI/file# [following]
# ...

# %%
def data_img(img):
    print('size = ', img.shape)
    print('max = ', inp.max(img))
    print('min = ', inp.min(img))

# %%
img_example = 'scale.png'

# %%
img1 = imread('scale.png')

# %%
X1 = img1[:,:,0]

# %%
plt.figure(figsize=(5,5))
plt.imshow(X1,cmap='gray')
plt.show()

# %% [markdown]
# Por ahora no usar

# %%
def data_img(img):
    print('size = ', img.shape)
    print('max = ', np.max(img))  # Using np.max
    print('min = ', np.min(img))  # Using np.min

# Now run the main code
d = 2 
(Nx,Mx) = X.shape
ix = range(0,Nx,d)
jx = range(0,Mx,d)
Ny = len(ix)
My = len(jx)
Y = np.zeros((Ny,My),np.uint8)
for i in range(Ny):
    for j in range(My):
        Y[i,j] = X[ix[i],jx[j]]
plt.figure(figsize=(8,8))
plt.imshow(X1,cmap='gray')
plt.show()
data_img(X1)
# Out:
# size =  (512, 512)
# max =  255
# min =  0

# %%
n = 256
h = imhist(X1,n=n)
plt.figure(figsize=(12,8))
plt.plot(range(n),h[0:n])
plt.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=9be9d3e5-4f25-48e6-912d-b59b8644d952' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
