# %%
# !pip install scikit-image watermark -q
# Out:
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
#El código generado puede estar sujeto a licencia
import numpy as np
import cv2
from cv2 import imread
import matplotlib.pyplot as plt

# %%
# %load_ext watermark
# %watermark
# %watermark --iversions
# Out:
# Last updated: 2025-03-31T04:08:34.526030+00:00
#
# Python implementation: CPython
# Python version       : 3.10.15
# IPython version      : 8.32.0
#
# Compiler    : GCC 10.2.1 20210110
# OS          : Linux
# Release     : 6.1.128-136.201.amzn2023.x86_64
# Machine     : x86_64
# Processor   :
# CPU cores   : 4
# Architecture: 64bit
#
# deepnote_toolkit: 0.1.0
# matplotlib      : 3.6.3
# numpy           : 1.25.2
# cv2             : 4.11.0

# %% [markdown]
# ## Input

# %%
# !wget https://d1lfxha3ugu3d4.cloudfront.net/images/opencollection/archives/size2/S03i3165l01.jpg
#https://scikit-image.org/docs/stable/api/skimage.data.html#skimage.data.coins
#https://opencollection.brooklynmuseum.org/archives/image/51611
# Out:
# --2025-03-31 04:08:34--  https://d1lfxha3ugu3d4.cloudfront.net/images/opencollection/archives/size2/S03i3165l01.jpg
# Resolving d1lfxha3ugu3d4.cloudfront.net (d1lfxha3ugu3d4.cloudfront.net)... 3.171.73.97, 3.171.73.196, 3.171.73.228, ...
# Connecting to d1lfxha3ugu3d4.cloudfront.net (d1lfxha3ugu3d4.cloudfront.net)|3.171.73.97|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30340 (30K) [image/jpeg]
# Saving to: ‘S03i3165l01.jpg’
#
# S03i3165l01.jpg     100%[===================>]  29.63K  --.-KB/s    in 0.001s
#
# 2025-03-31 04:08:34 (35.0 MB/s) - ‘S03i3165l01.jpg’ saved [30340/30340]

# %% [markdown]
# ## Leer imagenes

# %%
img = imread('S03i3165l01.jpg')
plt.imshow(img)
plt.show()

# %% [markdown]
# ## Funcion

# %%
def data_img(img):
  print('Tamaño = ',img.shape)
  print('Max = ',np.max(img))
  print('Min = ',np.min(img))

data_img(img)
# Out:
# Tamaño =  (303, 384, 3)
# Max =  252
# Min =  1

# %% [markdown]
# ## Recortar

# %%
# Primero alto, después ancho
img_cropped = img[0:80, 300:370]
plt.imshow(img_cropped)

# %%
# Primero alto, después ancho
img_cropped = img[150:220, 310:384]
plt.imshow(img_cropped)

# %%
RGB = (0, 0, 0) #negro ausencia de color
RGB = (255, 255, 255) #blanco
M = (0) #monocromo

# %% [markdown]
# ## Selección del primer canal de color

# %%
X = img_cropped[:,:,0]
data_img(X)
# Out:
# Tamaño =  (70, 74)
# Max =  218
# Min =  12

# %%
plt.imshow(X,cmap='gray')
plt.show()

# %%
data_img(img_cropped)
# Out:
# Tamaño =  (70, 74, 3)
# Max =  218
# Min =  12

# %%
img = imread('S03i3165l01.jpg')
plt.imshow(img)
plt.show()

# %%
# Primero ancho y despues alto
img_resize = cv2.resize(img_cropped, (60, 60))
plt.imshow(img_resize)

# %%
# Apilado vertical
ver = np.vstack((img_resize, img_resize))
plt.imshow(ver);

# %%
# Primero ancho y despues alto
img_resize = cv2.resize(img_cropped, (60, 60))
plt.imshow(img_resize)

# %% [markdown]
# ## Me da informacion del color (ojo es BGR)

# %%
img_cropped[0:0]
# Out:
# array([], shape=(0, 74, 3), dtype=uint8)

# %%
X[0:0]
# Out:
# array([], shape=(0, 74), dtype=uint8)

# %%
pixel1 = (255,0,0)
pixel2 = (0,255,0)
pixel3 = (0,0,255)

# %%
plt.imshow([[pixel1,pixel2,pixel3,]])

# %%
# !wget https://www2.eecs.berkeley.edu/Research/Projects/CS/vision/bsds/BSDS300/html/images/plain/normal/color/198023.jpg
# Out:
# --2025-03-31 04:08:37--  https://www2.eecs.berkeley.edu/Research/Projects/CS/vision/bsds/BSDS300/html/images/plain/normal/color/198023.jpg
# Resolving www2.eecs.berkeley.edu (www2.eecs.berkeley.edu)... 128.32.244.190
# Connecting to www2.eecs.berkeley.edu (www2.eecs.berkeley.edu)|128.32.244.190|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39350 (38K) [image/jpeg]
# Saving to: ‘198023.jpg.4’
#
# 198023.jpg.4        100%[===================>]  38.43K  --.-KB/s    in 0.06s
#
# 2025-03-31 04:08:38 (599 KB/s) - ‘198023.jpg.4’ saved [39350/39350]

# %%
img = imread('198023.jpg')
plt.imshow(img)
plt.show()

# %%
img[0:0]
# Out:
# array([], shape=(0, 321, 3), dtype=uint8)

# %%
pixel1 = (0,321,3)

# %%
plt.imshow([[pixel1]])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img_canny = cv2.Canny()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 img_canny = cv2.Canny()
#
# error: OpenCV(4.11.0) :-1: error: (-5:Bad argument) in function 'Canny'
# > Overload resolution failed:
# >  - Canny() missing required argument 'image' (pos 1)
# >  - Canny() missing required argument 'dx' (pos 1)
# >  - Canny() missing required argument 'image' (pos 1)
# >  - Canny() missing required argument 'dx' (pos 1)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=9be9d3e5-4f25-48e6-912d-b59b8644d952' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
